# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/SpeechTech/MDD_Challenge
# Out:
# /content/drive/MyDrive/SpeechTech/MDD_Challenge

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â”â” 3.1/3.1 MB 54.8 MB/s eta 0:00:00
# ...

# %%
# !python src/main.py
# Out:
# Vocabulary: 122 tokens (121 phonemes + CTC blank)
# Device: cuda
# Train: 2544, Val: 318
# ...
# Loading weights: 100% 211/211 [00:00<00:00, 1467.66it/s, Materializing param=masked_spec_embed]
# Wav2Vec2Model LOAD REPORT from: nguyenvulebinh/wav2vec2-base-vietnamese-250h
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.bias   | UNEXPECTED |  |
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable params: 106,051,323
# Epoch 1/20: 100% 159/159 [02:41<00:00,  1.01s/it, loss=4.4888]
# Validating: 100% 20/20 [00:23<00:00,  1.18s/it]
# Epoch 1: train_loss=26.3716, val_loss=4.4061, val_PER=1.0000
# Checkpoint saved to outputs/checkpoints
# Epoch 2/20: 100% 159/159 [03:02<00:00,  1.15s/it, loss=4.0227]
# Validating: 100% 20/20 [00:24<00:00,  1.22s/it]
# Epoch 2: train_loss=4.3994, val_loss=3.8511, val_PER=0.9816
# ...

# %%
# !python src/inference.py \
    --test_csv MDD-Challenge-2025-public-test/metadata/public_test_phones.csv \
    --audio_dir MDD-Challenge-2025-public-test/audio_data/public_test \
    --checkpoint outputs/checkpoints/model.pt \
    --vocab outputs/vocab.json \
    --processor outputs/processor \
    --output predictions.csv
# Out:
# Using device: cuda
# Test samples: 718
# Vocab size: 122
# ...
# Loading weights: 100% 211/211 [00:00<00:00, 966.48it/s, Materializing param=masked_spec_embed]
# Wav2Vec2Model LOAD REPORT from: nguyenvulebinh/wav2vec2-base-vietnamese-250h
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.bias   | UNEXPECTED |  |
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully
# Predictions saved to predictions.csv
# Sample predictions:
#                         id                                            predict
# 0    bia-dat_1618490611607  É“ o-4 É“ e-4 tz É“ É— É“ tz s É”-4 kpz É“ t É™Ë-4 É“ É”...
# 1  tuoi-phia_1618720389743                              t w o-3 iz s É›-0 aË-0
# 2  tuoi-phia_1618720406706                                  t w o-3 iz f iÉ™-2
# ...

# %%
# !python MDD-Metrics/evaluate.py \
    MDD-Challenge-2025-public-test/metadata/public_test_phones.csv \
    predictions.csv
# Out:
# F1: 0.408492
# PER: 0.0893854748603352
# DER: 0.37209302325581395

# %%
# !python src/inference.py \
    --test_csv /content/drive/MyDrive/SpeechTech/MDD_Challenge/MDD-Challenge-2025-private-test/metadata/private_test_submission.csv \
    --audio_dir /content/drive/MyDrive/SpeechTech/MDD_Challenge/MDD-Challenge-2025-private-test/audio_data/private_test \
    --checkpoint outputs/checkpoints/model.pt \
    --vocab outputs/vocab.json \
    --processor outputs/processor \
    --output private_predictions.csv
# Out:
# Using device: cuda
# Test samples: 856
# Vocab size: 122
# config.json: 100% 1.65k/1.65k [00:00<00:00, 2.42MB/s]
# ...
# pytorch_model.bin: 100% 378M/378M [00:03<00:00, 110MB/s]
# Loading weights: 100% 211/211 [00:00<00:00, 33891.09it/s]
# [transformers] Wav2Vec2Model LOAD REPORT from: nguyenvulebinh/wav2vec2-base-vietnamese-250h
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.bias   | UNEXPECTED |  |
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors: 100% 378M/378M [00:02<00:00, 135MB/s]
# Model loaded successfully
# Predictions saved to private_predictions.csv
# Sample predictions:
#                         id             predict
# 0  nang-giai_1618731750770  n a-0 Å‹z z aË-1 iz
# 1  nang-giai_1618731781800  n a-0 Å‹z z aË-2 iz
# 2  nang-giai_1618732605210   n a-0 Å‹z z a-3 iz
# ...
